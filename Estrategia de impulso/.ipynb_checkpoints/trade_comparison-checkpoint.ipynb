# %% [markdown]
# # Comparación de estrategias de Swing Trading: Buy&Hold VS 3MM

# %% [markdown]
# ### Script de comparación

# %%
def trade_comparison(csv, equity, n_acciones, comision_fija, comision_por_accion, ref_value, p_mmr, p_mmi, p_mml):
    
    #IMPORTACIÓN DE MÓDULOS
    
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    plt.rc("figure", figsize=[16,9])

    #FUNCIONES AUXILIARES

    def MME(N,data):
        MME=N*["NaN"]
        MME.append(np.mean(data[ref_value][0:N-1]))
        x=data.shape[0]-N
        counter=N
        for i in range(x):
            MME.append(np.mean(data[ref_value][counter-N:counter]))
            counter+=1
        return MME

    def AnadirColumna(lista, nombre_lista, DataFrame):
        np.array(lista)
        NewCol=pd.DataFrame(lista, columns=[nombre_lista])
        DataFrame=pd.concat([DataFrame, NewCol], axis=1)
        return DataFrame

    #IMPORTACIÓN DE ARCHIVO Y PREPARACIÓN DEL MISMO
    
    data_original=pd.read_csv(csv)
    data=data_original
    data=data.drop(["Adj Close"], axis=1)
    data=data.dropna(axis="rows", how="any")
    data["Mean Value"]=(data["High"]+data["Low"])/2

    MME_intermedia=MME(p_mmi,data)
    MME_rapida=MME(p_mmr,data)
    MME_lenta=MME(p_mml,data)
    data=AnadirColumna(MME_rapida,"MME_rapida",data)
    data=AnadirColumna(MME_intermedia,"MME_intermedia",data)
    data=AnadirColumna(MME_lenta,"MME_lenta",data)
    data.dropna(axis=0, how="any")
    data=data[p_mml:-1]
    data.head()

    #GRAFICADO DE LA COTIZACIÓN Y DE LAS MEDIAS
    
    plt.rc("figure", figsize=[19,7])
    plt.plot(data[ref_value])
    plt.plot(data["MME_rapida"])
    plt.plot(data["MME_intermedia"])
    plt.plot(data["MME_lenta"])
    plt.legend((ref_value,"MME_rapida","MME_intermedia","MME_lenta"))
    plt.show()

    #RESULTADOS PARA LA ESTRATEGIAS BUY & HOLD

    compra=data[ref_value][p_mml]
    venta=data[ref_value][-1:]
    comision=2*(comision_fija+comision_por_accion*n_acciones)
    profit=float(venta-compra-comision)
    
    
    ebit_integro_BH=venta-compra
    rent_integra_BH=ebit_integro_BH/compra
    ebit_rel_BH=equity*rent_integra_BH
    ebitda_rel_BH=ebit_rel_BH-comision
    rent_neta_BH=ebitda_rel_BH/equity
    print("\n\n"+21*"*"+"\nESTRATEGIA BUY & HOLD\n"+21*"*"+"\n")
    print("Compra el %s en %.2f$, venta el %s en %.2f$. \nPara un capital de %d$, el beneficio es: %.2f$. Una rentabilidad neta del %.2f\n\n" %(data["Date"][p_mml],compra,data["Date"][data.shape[0]],venta,equity,ebitda_rel_BH,rent_neta_BH))
    
    
    

    df=data
    for i in range(df.shape[0]):
        if ((df["MME_lenta"][i+p_mml] or df["MME_rapida"][i+p_mml] or df["MME_intermedia"][i+p_mml]) > df[ref_value][i+p_mml]):
            df=df.drop([i+p_mml], axis=0)

    dias=df.index.tolist()
    precios=df[ref_value].tolist()
    fechas=df["Date"].tolist()

    #RESULTADOS PARA LA ESTRATEGIA DE IMPULSO

    print(21*"*"+"\nESTRATEGIA DE IMPULSO\n"+21*"*"+"\n")
    compras=0
    ventas=0
    n=p_mml+2
    operaciones=0
    lenght=df.shape[0]
    while n < (lenght-1):
        if dias[n] != (dias[n-1]+1):
            print("El día %s inicia una compra a %.2f" %(fechas[n], precios[n]))
            compras += precios[n]
            operaciones += 1
            ultimo="compra"
            if operaciones==1:
                primera="compra"
                valor=precios[n]
        if dias[n] != (dias[n+1]-1):
            if operaciones!=0:
                print("El día %s se cierra una venta a %.2f" %(fechas[n], precios[n]))
            ventas += precios[n]
            operaciones += 1
            ultimo="venta"
            if operaciones==1:
                primera="venta"
                valor=precios[n]
        n+=1
    #print(compras,ventas, valor)


    if ultimo=="compra":
        ventas += float(df[ref_value][-1:])
    if primera=="venta":
        ventas -=valor
    
    
    ebit_integro_IM=ventas-compras
    rent_integra_IM=ebit_integro_IM/valor
    ebit_rel_IM=equity*rent_integra_IM
    ebitda_rel_IM=ebit_rel_IM-operaciones*(comision_fija+comision_por_accion*n_acciones)
    rent_neta_IM=ebitda_rel_IM/equity
    print("Beneficio por acción: %.2f$\nBeneficio para %d$: %.2f$\nRentabilidad neta: %.2f\nComisiones: %.2f$" %(ebit_integro_IM,equity,ebitda_rel_IM,rent_neta_IM,operaciones*(comision_fija+comision_por_accion*n_acciones)))


    #GRÁFICA COMPARATIVA DE RESULTADOS
    
    print("\n\n"+25*"*"+"\nCOMPARACIÓN DE RESULTADOS\n"+25*"*"+"\n")
    plt.rc("figure", figsize=[5,5])
    plt.bar(["Buy & Hold","Impulso"] ,[ebitda_rel_BH,ebitda_rel_IM])
    plt.xlabel("Estrategias")
    plt.ylabel("Beneficio Neto")
    plt.title("Comparación de estrategias")
    plt.show()

    #RESUMEN DE RESULTADOS

    print(16*"*"+"\nRESUMEN DE DATOS\n"+16*"*"+"\n")
    print("Buy&Hold: con %d$, se obtiene un beneficio de %.2f$ en 2 operaciones \nImpulso: con %d$, se obtiene un beneficio de %.2f$ tras %d operaciones" %(equity,ebitda_rel_BH,equity,ebitda_rel_IM, operaciones))
    dif=ebitda_rel_IM-ebitda_rel_BH
    print("DIFERENCIA: %.2f$" %dif)

# %% [markdown]
# ### Datos de la comparación

# %%
csv="BTC2.csv" #Nombre del archivo que contiene los datos de la cotización según Yahoo Finance
equity=50  #Capital de inversión
n_acciones=1  #Número de acciones para operar
comision_fija=0.5  #Comisión fija en cada operación
comision_por_accion=0.004  ##Comisión variable por operación en funcion del número de acciones
ref_value="Mean Value"  #Valor de referencia del algoritmo y de las medias móviles: "Mean Value", "Open", "High", "Low", "Close"
p_mmr=1  #Período de la Media Móvil Rápida
p_mmi=3  #Período de la Media Móvil Intermedia
p_mml=5  #Período de la Media Móvil Lenta
tax=0.5+0.004 #Comisión del broker por acción y operación (compra o venta)

# %% [markdown]
# ### Resultados

# %%
trade_comparison(csv, equity, n_acciones, comision_fija, comision_por_accion, ref_value, p_mmr, p_mmi, p_mml)
# Out:
# *********************
# ESTRATEGIA BUY & HOLD
# *********************
#
# Compra el 2019-08-26 en 9261.59$, venta el 2020-12-15 en 18781.01$.
# Para un capital de 50$, el beneficio es: 50.38$. Una rentabilidad neta del 1.01
#
#
# *********************
# ESTRATEGIA DE IMPULSO
# *********************
#
# El día 2019-09-13 inicia una compra a 9334.03
# El día 2019-09-17 se cierra una venta a 9280.65
# El día 2019-10-01 inicia una compra a 7650.97
# El día 2019-10-03 se cierra una venta a 7543.69
# El día 2019-10-08 inicia una compra a 7536.14
# El día 2019-10-12 se cierra una venta a 7579.64
# El día 2019-10-21 inicia una compra a 7394.82
# El día 2019-10-22 se cierra una venta a 7355.49
# El día 2019-10-25 inicia una compra a 7297.46
# El día 2019-10-30 se cierra una venta a 8298.85
# El día 2019-11-04 inicia una compra a 8400.70
# El día 2019-11-07 se cierra una venta a 8401.19
# El día 2019-11-28 inicia una compra a 6894.70
# El día 2019-12-01 se cierra una venta a 6744.38
# El día 2019-12-06 inicia una compra a 6754.46
# El día 2019-12-09 se cierra una venta a 6771.38
# El día 2019-12-19 inicia una compra a 6467.38
# El día 2019-12-25 se cierra una venta a 6569.80
# El día 2020-01-04 inicia una compra a 6602.85
# El día 2020-01-19 se cierra una venta a 8015.23
# El día 2020-01-27 inicia una compra a 7974.51
# El día 2020-02-03 se cierra una venta a 8492.22
# El día 2020-02-05 inicia una compra a 8575.39
# El día 2020-02-15 se cierra una venta a 9332.60
# El día 2020-02-23 inicia una compra a 9035.11
# El día 2020-02-23 se cierra una venta a 9035.11
# El día 2020-03-05 inicia una compra a 8011.99
# El día 2020-03-07 se cierra una venta a 7998.03
# El día 2020-03-19 inicia una compra a 5369.39
# El día 2020-03-27 se cierra una venta a 5965.39
# El día 2020-04-01 inicia una compra a 5857.50
# El día 2020-04-09 se cierra una venta a 6680.78
# El día 2020-04-17 inicia una compra a 6534.16
# El día 2020-04-20 se cierra una venta a 6479.49
# El día 2020-04-23 inicia una compra a 6757.64
# El día 2020-05-09 se cierra una venta a 8884.97
# El día 2020-05-14 inicia una compra a 8811.00
# El día 2020-05-19 se cierra una venta a 8858.10
# El día 2020-05-28 inicia una compra a 8466.70
# El día 2020-06-02 se cierra una venta a 8778.39
# El día 2020-06-09 inicia una compra a 8636.89
# El día 2020-06-10 se cierra una venta a 8631.81
# El día 2020-06-17 inicia una compra a 8383.80
# El día 2020-06-19 se cierra una venta a 8343.67
# El día 2020-06-21 inicia una compra a 8366.14
# El día 2020-06-24 se cierra una venta a 8390.64
# El día 2020-07-01 inicia una compra a 8189.07
# El día 2020-07-02 se cierra una venta a 8140.55
# El día 2020-07-06 inicia una compra a 8166.05
# El día 2020-07-09 se cierra una venta a 8250.98
# El día 2020-07-21 inicia una compra a 8104.76
# El día 2020-08-10 se cierra una venta a 10055.28
# El día 2020-08-14 inicia una compra a 10071.29
# El día 2020-08-18 se cierra una venta a 10197.01
# El día 2020-08-30 inicia una compra a 9744.67
# El día 2020-09-02 se cierra una venta a 9786.80
# El día 2020-09-10 inicia una compra a 8749.42
# El día 2020-09-20 se cierra una venta a 9252.91
# El día 2020-09-25 inicia una compra a 9177.31
# El día 2020-09-30 se cierra una venta a 9188.30
# El día 2020-10-05 inicia una compra a 9122.68
# El día 2020-10-06 se cierra una venta a 9083.08
# El día 2020-10-08 inicia una compra a 9146.41
# El día 2020-10-16 se cierra una venta a 9720.23
# El día 2020-10-18 inicia una compra a 9743.54
# El día 2020-11-25 se cierra una venta a 15943.25
# El día 2020-11-30 inicia una compra a 15822.54
# El día 2020-12-04 se cierra una venta a 15740.21
# El día 2020-12-07 inicia una compra a 15816.30
# El día 2020-12-07 se cierra una venta a 15816.30
# El día 2020-12-13 inicia una compra a 15735.28
# Beneficio por acción: 19684.36$
# Beneficio para 50$: 68.48$
# Rentabilidad neta: 1.37
# Comisiones: 36.29$
#
#
# *************************
# COMPARACIÓN DE RESULTADOS
# *************************
# ****************
# RESUMEN DE DATOS
# ****************
#
# Buy&Hold: con 50$, se obtiene un beneficio de 50.38$ en 2 operaciones
# Impulso: con 50$, se obtiene un beneficio de 68.48$ tras 72 operaciones
# DIFERENCIA: 18.10$
